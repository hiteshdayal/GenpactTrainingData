# %% [markdown]
# ## MATPLOTLIB: DATA VISUALIZATION

# %% [markdown]
# ### Importing required Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.linspace(0, 10, 50)
print (x, type(x))
# Out:
# [ 0.          0.20408163  0.40816327  0.6122449   0.81632653  1.02040816
#   1.2244898   1.42857143  1.63265306  1.83673469  2.04081633  2.24489796
#   2.44897959  2.65306122  2.85714286  3.06122449  3.26530612  3.46938776
#   3.67346939  3.87755102  4.08163265  4.28571429  4.48979592  4.69387755
#   4.89795918  5.10204082  5.30612245  5.51020408  5.71428571  5.91836735
#   6.12244898  6.32653061  6.53061224  6.73469388  6.93877551  7.14285714
#   7.34693878  7.55102041  7.75510204  7.95918367  8.16326531  8.36734694
#   8.57142857  8.7755102   8.97959184  9.18367347  9.3877551   9.59183673
#   9.79591837 10.        ] <class 'numpy.ndarray'>

# %%
sinus = np.sin(x)
print (sinus, type(sinus))
# Out:
# [ 0.          0.20266794  0.39692415  0.57470604  0.72863478  0.85232157
#   0.94063279  0.98990308  0.99808748  0.96484631  0.89155923  0.78126802
#   0.63855032  0.46932961  0.2806294   0.08028167 -0.12339814 -0.32195632
#  -0.50715171 -0.67129779 -0.80758169 -0.91034694 -0.97532829 -0.99982867
#  -0.9828312  -0.92504137 -0.82885774 -0.6982724  -0.53870529 -0.35677924
#  -0.16004509  0.04333173  0.24491007  0.43632343  0.6096272   0.75762842
#   0.8741843   0.9544572   0.99511539  0.99447137  0.95255185  0.8710967
#   0.75348673  0.60460332  0.43062587  0.23877532  0.0370144  -0.16628279
#  -0.36267843 -0.54402111] <class 'numpy.ndarray'>

# %%
plt.plot(x, sinus)
plt.show()

# %%
plt.plot(x, sinus, 'om')
plt.show()

# %%
plt.plot(x, sinus, '*')
plt.show()

# %%
plt.plot(x, sinus, '--g')
plt.show()

# %%
plt.plot(x, sinus, '-')
plt.show()

# %%
plt.plot(x, sinus, '-r')
plt.show()

# %%
# rapid multiplot
x = np.linspace(0, 10, 50)
sinus = np.sin(x)
cosinus = np.cos(x)
plt.plot(x, sinus, "-b", x, sinus, "or", x, cosinus, "-r", x, cosinus, "ob")
plt.xlabel("Plotting x values...")
plt.ylabel("Plotting Sinus and Cosunus values...")
plt.title("X vs. Sinus and Cosinus")
plt.show()

# %%
# step by step
plt.plot(x, sinus, label = 'Sinus', color = 'blue', linestyle = '--', linewidth = 2)
plt.plot(x, cosinus, label = 'Cosinus', color = "red", linestyle = '-', linewidth = 2)
plt.xlabel("Plotting x values...")
plt.ylabel("Plotting Sinus and Cosunus values...")
plt.title("X vs. Sinus and Cosinus")
plt.legend(loc = 0)
plt.show()

# %% [raw]
# Class Assignment:
# Draw a circle with center point at (0, 0) position with radius 10

# %%
# x ** 2 + y ** 2 = r ** 2
plt.figure(figsize = (5, 5))
r = 10
x = np.linspace(-10, 10, 100)
y = np.sqrt(r ** 2 - x ** 2)
plt.plot(x, y, "-r")
plt.plot(x, -y, "--b")
plt.show()

# %% [markdown]
# ### Scatter 2D Plots

# %%
try:
    salary = pd.read_csv("salary_table.csv")
    df = salary.copy()
    print ("DataFrame has been populated with CSV file content...")
except:
    print ("File access error...")
# Out:
# DataFrame has been populated with CSV file content...

# %%
salary.head()
# Out:
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %%
salary.describe()
# Out:
#              salary  experience
# count     46.000000   46.000000
# mean   17270.195652    7.500000
# std     4716.631513    5.171503
# min    10535.000000    1.000000
# 25%    13320.750000    3.000000
# 50%    16436.000000    6.000000
# 75%    20719.750000   11.000000
# max    27837.000000   20.000000

# %%
colors_edu = {'Bachelor':'r', 'Master':'g', 'Ph.D':'b'}
print (colors_edu, type(colors_edu))
plt.scatter(df['experience'], df['salary'], c = df['education'].apply(lambda col: colors_edu[col]))
plt.show()
# Out:
# {'Bachelor': 'r', 'Master': 'g', 'Ph.D': 'b'} <class 'dict'>

# %%
print (df['experience'][:5])
print (df.experience[:5])
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: experience, dtype: int64
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: experience, dtype: int64

# %%
colors_edu = {'Bachelor':'r', 'Master':'g', 'Ph.D':'b'}
print (colors_edu, type(colors_edu))
plt.scatter(df.experience, df.salary, c = df.education.apply(lambda col: colors_edu[col]))
plt.show()
# Out:
# {'Bachelor': 'r', 'Master': 'g', 'Ph.D': 'b'} <class 'dict'>

# %%
df.head()
# Out:
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %%
# group by education x management => 6 groups (3 x 2)
for values, data in df.groupby(['education', 'management']):
    edu, manager = values
    print (values, edu, manager)
    print (data)
# Out:
# ('Bachelor', 'N') Bachelor N
#     salary  experience education management
# 7    10535           2  Bachelor          N
# 13   11417           4  Bachelor          N
# 20   12336           6  Bachelor          N
# 28   13548           8  Bachelor          N
# 29   14467          10  Bachelor          N
# 34   14861          11  Bachelor          N
# 37   15990          13  Bachelor          N
# 43   17483          16  Bachelor          N
# 45   19346          20  Bachelor          N
# ('Bachelor', 'Y') Bachelor Y
#     salary  experience education management
# 0    13876           1  Bachelor          Y
# 10   14975           3  Bachelor          Y
# 19   15965           5  Bachelor          Y
# 24   16978           7  Bachelor          Y
# 26   17404           8  Bachelor          Y
# ('Master', 'N') Master N
#     salary  experience education management
# 3    11283           1    Master          N
# 6    11772           2    Master          N
# ...

# %%
plt.figure(figsize=(6, 5))
symbols_manag = {'Y':"*", 'N':'.'}
colors_edu = {'Bachelor':'r', 'Master':'g', 'Ph.D':'b'}
for values, data in df.groupby(['education', 'management']):
    edu, manager = values
    plt.scatter(data.experience, data.salary, marker = symbols_manag[manager], color = colors_edu[edu], s = 150, label = manager + " / " + edu)
plt.xlabel("Experiencs (in Years) ->")
plt.ylabel("Salary (in INR) ->")
plt.title("Salary Vs. Experience...")
plt.legend()
plt.show()

# %% [markdown]
# ### Saving Figures

# %%
# in bitmap format
x = np.linspace(0, 10, 50)
plt.plot(x, sinus)
plt.savefig("sinus.png")
plt.close()

# %%
# in bitmap format
x = np.linspace(0, 10, 50)
plt.plot(x, sinus)
plt.savefig("sinus.svg")
plt.close()

# %%
# in PDF format
x = np.linspace(0, 10, 50)
plt.plot(x, sinus)
plt.savefig("sinus.pdf")
plt.close()

# %% [markdown]
# ### Exploring data with seaborn

# %%
sns.boxplot(x="education", y="salary", data = df)
# Out:
# <AxesSubplot:xlabel='education', ylabel='salary'>

# %%
sns.boxplot(x="education", y="salary", hue = "management", data = df)
# Out:
# <AxesSubplot:xlabel='education', ylabel='salary'>

# %%
sns.boxplot(x = "management", y = "salary", hue = "education", data = df)
# Out:
# <AxesSubplot:xlabel='management', ylabel='salary'>

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# setup some generic data
N = 37
x, y = np.mgrid[:N, :N]
Z = (np.cos(x*0.2) + np.sin(y*0.3))

# mask out the negative and positive values, respectively
Zpos = np.ma.masked_less(Z, 0)
Zneg = np.ma.masked_greater(Z, 0)

fig, (ax1, ax2, ax3) = plt.subplots(figsize=(13, 3), ncols=3)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax1.imshow(Zpos, cmap='Blues', interpolation='none')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax1)

# repeat everything above for the negative data
# you can specify location, anchor and shrink the colorbar
neg = ax2.imshow(Zneg, cmap='Reds_r', interpolation='none')
fig.colorbar(neg, ax=ax2, location='right', anchor=(0, 0.3), shrink=0.7)

# Plot both positive and negative values between +/- 1.2
pos_neg_clipped = ax3.imshow(Z, cmap='RdBu', vmin=-1.2, vmax=1.2,
                             interpolation='none')
# Add minorticks on the colorbar to make it easy to read the
# values off the colorbar.
cbar = fig.colorbar(pos_neg_clipped, ax=ax3, extend='both')
cbar.minorticks_on()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-d8fe9e4a1104> in <module>
#      25 # you can specify location, anchor and shrink the colorbar
#      26 neg = ax2.imshow(Zneg, cmap='Reds_r', interpolation='none')
# ---> 27 fig.colorbar(neg, ax=ax2, location='right', anchor=(0, 0.3), shrink=0.7)
#      28
#      29 # Plot both positive and negative values between +/- 1.2
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2341                              'panchor']
#    2342         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2343         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2344
#    2345         self.sca(current_ax)
#
# ~\anaconda3\lib\site-packages\matplotlib\colorbar.py in colorbar_factory(cax, mappable, **kwargs)
# ...

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill",
            hue="smoker", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True)
